# %%
# !pip install bokeh
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting bokeh
#   Downloading bokeh-3.2.0-py3-none-any.whl (7.8 MB)
#      ---------------------------------------- 7.8/7.8 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=2.9 in c:\users\crash\appdata\roaming\python\python311\site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\crash\appdata\roaming\python\python311\site-packages (from bokeh) (1.0.7)
# Requirement already satisfied: numpy>=1.16 in c:\users\crash\appdata\roaming\python\python311\site-packages (from bokeh) (1.23.5)
# Requirement already satisfied: packaging>=16.8 in c:\users\crash\appdata\roaming\python\python311\site-packages (from bokeh) (23.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\crash\appdata\roaming\python\python311\site-packages (from bokeh) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\crash\appdata\roaming\python\python311\site-packages (from bokeh) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\crash\appdata\roaming\python\python311\site-packages (from bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\crash\appdata\roaming\python\python311\site-packages (from bokeh) (6.2)
# Collecting xyzservices>=2021.09.1
#   Downloading xyzservices-2023.5.0-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.5/56.5 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\crash\appdata\roaming\python\python311\site-packages (from Jinja2>=2.9->bokeh) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\crash\appdata\roaming\python\python311\site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\crash\appdata\roaming\python\python311\site-packages (from pandas>=1.2->bokeh) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\crash\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)
# Installing collected packages: xyzservices, bokeh
# Successfully installed bokeh-3.2.0 xyzservices-2023.5.0
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import plotly.io as pio
import plotly.express as px
import plotly.offline as py
from bokeh.plotting import figure, output_file, save

# %%
#Read data
df=pd.read_csv('C:/Users/crash/Desktop/Dev Projects/Hackathon/GFG Olympics/Data/athlete_events.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df['Height']=df['Height'].fillna(df['Height'].mean())
df['Weight']=df['Weight'].fillna(df['Weight'].mean())
df['Age']=df['Age'].fillna(df['Age'].mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     271116 non-null  float64
#  4   Height  271116 non-null  float64
#  5   Weight  271116 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
sns.pairplot(df)
